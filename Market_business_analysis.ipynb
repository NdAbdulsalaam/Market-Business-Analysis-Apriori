# %% [markdown]
# # **Market Basket Analysis with Apriori Algorithm**
#
# ![image.png](https://i1.wp.com/www.edtechnology.in/wp-content/uploads/2019/06/Market-Basket-Analysis.jpg?fit=1920%2C1080)

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from mlxtend.frequent_patterns import apriori, association_rules
from pandas.plotting import parallel_coordinates

pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

import warnings
warnings.filterwarnings("ignore")

# %%
df_order = pd.read_csv("/kaggle/input/instacart-market-basket-analysis/order_products__prior.csv")
df_order.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
df_product = pd.read_csv("/kaggle/input/instacart-market-basket-analysis/products.csv")
df_product.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %% [markdown]
# Merging the files to get a single dataframe with both order and item details

# %%
df_items = pd.merge(df_order,df_product,how='inner',on='product_id')
df_items.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered        product_name  \
# 0         2       33120                  1          1  Organic Egg Whites
# 1        26       33120                  5          0  Organic Egg Whites
# 2       120       33120                 13          0  Organic Egg Whites
# 3       327       33120                  5          1  Organic Egg Whites
# 4       390       33120                 28          1  Organic Egg Whites
#
#    aisle_id  department_id
# 0        86             16
# 1        86             16
# 2        86             16
# 3        86             16
# 4        86             16

# %%
df_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32434489 entries, 0 to 32434488
# Data columns (total 7 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  int64
#  3   reordered          int64
#  4   product_name       object
#  5   aisle_id           int64
#  6   department_id      int64
# dtypes: int64(6), object(1)
# memory usage: 1.9+ GB

# %% [markdown]
# ### This data is too large. I'll be doing the following
# - Use the most frequently ordered items, that is, where `reordered` equals `1`.
# - Select the first `500,000` observations

# %%
df_items["reordered"].value_counts()
# Out:
# 1    19126536
# 0    13307953
# Name: reordered, dtype: int64

# %%
df_items = df_items[df_items["reordered"] == 1]
df_items = df_items.head(500000)

# Confirm changes
print(df_items["reordered"].value_counts())
# Out:
# 1    500000
# Name: reordered, dtype: int64

# %% [markdown]
# ## Change data type
#
# columns with `id` are expected to be object and not numerical

# %%
for col in df_items.columns:
    if ("id" in col) & (df_items[col].dtype != "object"):
        df_items[col] = df_items[col].astype(str)

# Confirm changes
df_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 0 to 703125
# Data columns (total 7 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   order_id           500000 non-null  object
#  1   product_id         500000 non-null  object
#  2   add_to_cart_order  500000 non-null  int64
#  3   reordered          500000 non-null  int64
#  4   product_name       500000 non-null  object
#  5   aisle_id           500000 non-null  object
#  6   department_id      500000 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 30.5+ MB

# %%
df_items.boxplot();

# %%
#  Check the number of items that are usually purchased together
df_items["add_to_cart_order"].hist();

# %%
df_items.describe().T
# Out:
#                        count  mean   std   min   25%   50%    75%     max
# add_to_cart_order 500000.000 7.017 6.064 1.000 3.000 5.000 10.000 108.000
# reordered         500000.000 1.000 0.000 1.000 1.000 1.000  1.000   1.000

# %%
df_items.describe(include = 'O').T
# Out:
#                 count  unique                   top    freq
# order_id       500000  436676                     4      12
# product_id     500000      31                 21903  186884
# product_name   500000      31  Organic Baby Spinach  186884
# aisle_id       500000      22                   123  188248
# department_id  500000       9                     4  368042

# %%
# Check the department from which most of the sales come from.
df_items[["order_id", "department_id"]].groupby("department_id").count().plot(kind = "bar");

# %% [markdown]
# # I'll only need the `order_id` and the `product_name`

# %%
df = df_items[['order_id','product_name']].copy()
df.rename(columns={'order_id':'order','product_name':'items'},inplace=True)
df['marker']=1

# %%
df.head()
# Out:
#   order               items  marker
# 0     2  Organic Egg Whites       1
# 3   327  Organic Egg Whites       1
# 4   390  Organic Egg Whites       1
# 5   537  Organic Egg Whites       1
# 6   582  Organic Egg Whites       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 0 to 703125
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   order   500000 non-null  object
#  1   items   500000 non-null  object
#  2   marker  500000 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 15.3+ MB

# %% [markdown]
# Making transaction data ready for Frequent item set mining.

# %% [markdown]
# # 2.Preparing Invoice-Product Matrix for ARL Data Structure

# %%
def make_matrix(df):
        return df.groupby(['order','items'])['marker'].sum().unstack().fillna(0). \
            applymap(lambda x: 1 if x > 0 else 0)

# %%
df_matrix = make_matrix(df)

# %% [markdown]
# # 3. Determination of Association Rules**Frequent Itemsets Mining**

# %%
freq_itemsets = apriori(df_matrix, min_support=0.01, use_colnames=True)

# Collecting the inferred rules in a dataframe 
rules = association_rules(freq_itemsets,metric='support',min_threshold=0.01)
rules.sort_values('support',ascending=False)
# Out:
#                 antecedents               consequents  antecedent support  \
# 4   (Michigan Organic Kale)    (Organic Baby Spinach)               0.107
# 5    (Organic Baby Spinach)   (Michigan Organic Kale)               0.428
# 2                 (Carrots)    (Organic Baby Spinach)               0.107
# 3    (Organic Baby Spinach)                 (Carrots)               0.428
# 0  (Bag of Organic Bananas)    (Organic Baby Spinach)               0.129
# 1    (Organic Baby Spinach)  (Bag of Organic Bananas)               0.428
# 6     (Organic Ginger Root)    (Organic Baby Spinach)               0.068
# 7    (Organic Baby Spinach)     (Organic Ginger Root)               0.428
# 8  (Unsweetened Almondmilk)    (Organic Baby Spinach)               0.086
# 9    (Organic Baby Spinach)  (Unsweetened Almondmilk)               0.428
#
#    consequent support  support  confidence  lift  leverage  conviction
# 4               0.428    0.021       0.196 0.457    -0.025       0.711
# ...

# %%
# Let's sort dataframe by lift:
rules.sort_values("lift", ascending=False)
# Out:
#                 antecedents               consequents  antecedent support  \
# 6     (Organic Ginger Root)    (Organic Baby Spinach)               0.068
# 7    (Organic Baby Spinach)     (Organic Ginger Root)               0.428
# 4   (Michigan Organic Kale)    (Organic Baby Spinach)               0.107
# 5    (Organic Baby Spinach)   (Michigan Organic Kale)               0.428
# 2                 (Carrots)    (Organic Baby Spinach)               0.107
# 3    (Organic Baby Spinach)                 (Carrots)               0.428
# 8  (Unsweetened Almondmilk)    (Organic Baby Spinach)               0.086
# 9    (Organic Baby Spinach)  (Unsweetened Almondmilk)               0.428
# 1    (Organic Baby Spinach)  (Bag of Organic Bananas)               0.428
# 0  (Bag of Organic Bananas)    (Organic Baby Spinach)               0.129
#
#    consequent support  support  confidence  lift  leverage  conviction
# 6               0.428    0.014       0.200 0.468    -0.016       0.715
# ...

# %%
# add extra another rule where support more than 0.2 for given itemset
filtered_rules = rules[(rules['antecedent support'] > 0.02)&
                        (rules['consequent support'] >0.01) &
                        (rules['confidence'] > 0.45) &
                        (rules['lift'] > 1.0)&
                        (rules['support']>0.195)]

# %%
def rules_to_coordinates(rules):
    rules['antecedent'] = rules['antecedents'].apply(lambda antecedent:list(antecedent)[0])
    rules['consequent'] = rules['consequents'].apply(lambda consequent:list(consequent)[0])
    rules['rule'] = rules.index
    return rules[['antecedent','consequent','rule']]

# %%
# Convert rules into coordinates suitable for use in a parallel coordinates plot
coords = rules_to_coordinates(rules)
# Generate parallel coordinates plot
plt.figure(figsize=(3,6))
parallel_coordinates(coords, 'rule',colormap = 'ocean')
plt.legend([])
plt.show()

# %% [markdown]
# From the plot it seems like the Organic Baby Spinach can be used as cross-selling with other products, it also acts as something to be offered with antecedents that is low. Thus, the customers are more likely to buy them if the Organci Baby Spinach is offered with cheaper price if they buy the antecedents that sold less in a store.

# %% [markdown]
# # 4.Suggesting a Product to Users at the Basket Stage
#
# For example, When X is bought, we can sort according to the probability of buying Y (confidence) and make a product offer, or we can make an offer according to how many times the probability of sales over the lift increases. We can also make a product recommendation with a hybrid filtering where support, lift and confidence are used together.

# %% [markdown]
# ***If a customer buys `Organic Baby Spinach`, which products would you recommend?***
# - Define a function to check for product name
# - Define a function for recommending a product

# %%
def check_product(item, df =df):
    product_name = df[df["items"] == item]["items"].unique()[0]
    return product_name

# %%
def recommend_product(item, df = df, qty = 5):
    products = item
    code_list = []
    name_list = []
    sorted_rules = rules.sort_values("lift", ascending=False)
    for idx, product in enumerate(sorted_rules["antecedents"]):
        for j in list(product):
            if j == products:
                code_list.append(list(sorted_rules.iloc[idx]["consequents"])[0])
                code_list = list(dict.fromkeys(code_list))
                
        # Print product name for the df 
    if len(code_list) <= 0:
        return "Invalid Product, try again!"
    else:
        for code in code_list:
            name_list.append(check_product(code))
    
    
    print(f"Recommended product(s) for {item} is/are:")
    for i, item in enumerate(name_list):
        print(i+1, item)

# %% [markdown]
# ***Let's list the top 5 most preferred products for `Organic Baby Spinach`***

# %%
 recommend_product("Organic Baby Spinach")
# Out:
# Recommended product(s) for Organic Baby Spinach is/are:
# 1 Organic Ginger Root
# 2 Michigan Organic Kale
# 3 Carrots
# 4 Unsweetened Almondmilk
# 5 Bag of Organic Bananas
